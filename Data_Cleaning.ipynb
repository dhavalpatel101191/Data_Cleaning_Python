# %%
import pandas as pd
df = pd.read_csv('../Sample Data/Machine_Data.csv')

# %%
df
# Out:
#                  Row Type       Iter Number             Power1  Speed1  \
# 0      first name: Person  last name: Human  date: end of time     NaN
# 1                     NaN               NaN                NaN     NaN
# 2                Row Type       Iter Number             Power1  Speed1
# 3                    Iter                 1                360     108
# 4                    Iter                 2                684     508
# ...                   ...               ...                ...     ...
# 76372                Iter                 6                879      73
# 76373             Average               979                641     531
# 76374             Maximum               783                172     941
# 76375            Std.Dev.               221                112     717
# 76376               Total               429                  -       -
#
#        Speed2  Electricity  Effort  Weight  Torque  Unnamed: 9 Unnamed: 10
# ...

# %%
drop_dp = df.drop(columns= ['Unnamed: 9','Unnamed: 10'])
drop_dp.head()
# Out:
#              Row Type       Iter Number             Power1  Speed1  Speed2  \
# 0  first name: Person  last name: Human  date: end of time     NaN     NaN
# 1                 NaN               NaN                NaN     NaN     NaN
# 2            Row Type       Iter Number             Power1  Speed1  Speed2
# 3                Iter                 1                360     108     863
# 4                Iter                 2                684     508     613
#
#    Electricity  Effort  Weight  Torque
# 0          NaN     NaN     NaN     NaN
# 1          NaN     NaN     NaN     NaN
# 2  Electricity  Effort  Weight  Torque
# 3          599     680     442     982
# 4          241     249     758     639

# %%
drop_NaN = drop_dp[drop_dp['Row Type'].notna()]

# %%
drop_NaN.head()
# Out:
#              Row Type       Iter Number             Power1  Speed1  Speed2  \
# 0  first name: Person  last name: Human  date: end of time     NaN     NaN
# 2            Row Type       Iter Number             Power1  Speed1  Speed2
# 3                Iter                 1                360     108     863
# 4                Iter                 2                684     508     613
# 5                Iter                 3                365     126     825
#
#    Electricity  Effort  Weight  Torque
# 0          NaN     NaN     NaN     NaN
# 2  Electricity  Effort  Weight  Torque
# 3          599     680     442     982
# 4          241     249     758     639
# 5          407     855     164      86

# %%
column_value = []
counter = 0

for i in drop_NaN['Row Type']:
    if 'first name' in i:
        counter += 1
    column_value.append(counter)

# %%
drop_NaN['New'] = column_value
# Out:
# C:\Users\Dhaval\Miniconda3\envs\Practice_Work\lib\site-packages\pandas\core\frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)

# %%
drop_NaN.head()
# Out:
#              Row Type       Iter Number             Power1  Speed1  Speed2  \
# 0  first name: Person  last name: Human  date: end of time     NaN     NaN
# 2            Row Type       Iter Number             Power1  Speed1  Speed2
# 3                Iter                 1                360     108     863
# 4                Iter                 2                684     508     613
# 5                Iter                 3                365     126     825
#
#    Electricity  Effort  Weight  Torque  New
# 0          NaN     NaN     NaN     NaN    1
# 2  Electricity  Effort  Weight  Torque    1
# 3          599     680     442     982    1
# 4          241     249     758     639    1
# 5          407     855     164      86    1

# %%
drop_Extra = drop_NaN[drop_NaN['Row Type'] != 'Row Type']

# %%
drop_Extra.head()
# Out:
#              Row Type       Iter Number             Power1 Speed1 Speed2  \
# 0  first name: Person  last name: Human  date: end of time    NaN    NaN
# 3                Iter                 1                360    108    863
# 4                Iter                 2                684    508    613
# 5                Iter                 3                365    126    825
# 6                Iter                 4                764    594    304
#
#   Electricity Effort Weight Torque  New
# 0         NaN    NaN    NaN    NaN    1
# 3         599    680    442    982    1
# 4         241    249    758    639    1
# 5         407    855    164     86    1
# 6         718    278    674    774    1

# %%
Name_Data = drop_Extra[drop_Extra['Row Type'].str.contains('first name')]
Name_Data.head()
# Out:
#               Row Type       Iter Number             Power1 Speed1 Speed2  \
# 0   first name: Person  last name: Human  date: end of time    NaN    NaN
# 14  first name: Person  last name: Human  date: end of time    NaN    NaN
# 28  first name: Person  last name: Human  date: end of time    NaN    NaN
# 42  first name: Person  last name: Human  date: end of time    NaN    NaN
# 56  first name: Person  last name: Human  date: end of time    NaN    NaN
#
#    Electricity Effort Weight Torque  New
# 0          NaN    NaN    NaN    NaN    1
# 14         NaN    NaN    NaN    NaN    2
# 28         NaN    NaN    NaN    NaN    3
# 42         NaN    NaN    NaN    NaN    4
# 56         NaN    NaN    NaN    NaN    5

# %%
drop_dp = df.drop(columns= ['Unnamed: 9','Unnamed: 10'])
drop_dp.head()
# Out:
#              Row Type       Iter Number             Power1  Speed1  Speed2  \
# 0  first name: Person  last name: Human  date: end of time     NaN     NaN
# 1                 NaN               NaN                NaN     NaN     NaN
# 2            Row Type       Iter Number             Power1  Speed1  Speed2
# 3                Iter                 1                360     108     863
# 4                Iter                 2                684     508     613
#
#    Electricity  Effort  Weight  Torque
# 0          NaN     NaN     NaN     NaN
# 1          NaN     NaN     NaN     NaN
# 2  Electricity  Effort  Weight  Torque
# 3          599     680     442     982
# 4          241     249     758     639

# %%
Name_Data.drop(columns= ['Speed1','Speed2','Electricity','Effort','Weight','Torque'], inplace=True)
# Out:
# C:\Users\Dhaval\Miniconda3\envs\Practice_Work\lib\site-packages\pandas\core\frame.py:4901: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
Name_Data.head()
# Out:
#               Row Type       Iter Number             Power1  New
# 0   first name: Person  last name: Human  date: end of time    1
# 14  first name: Person  last name: Human  date: end of time    2
# 28  first name: Person  last name: Human  date: end of time    3
# 42  first name: Person  last name: Human  date: end of time    4
# 56  first name: Person  last name: Human  date: end of time    5

# %%
Name_Data['Row Type'] = Name_Data['Row Type'].str[12:]
Name_Data['Iter Number'] = Name_Data['Iter Number'].str[11:]
Name_Data['Power1'] = Name_Data['Power1'].str[5:]
# Out:
# C:\Users\Dhaval\Miniconda3\envs\Practice_Work\lib\site-packages\pandas\core\frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)

# %%
Name_Data.head()
# Out:
#    Row Type Iter Number        Power1  New
# 0    Person       Human   end of time    1
# 14   Person       Human   end of time    2
# 28   Person       Human   end of time    3
# 42   Person       Human   end of time    4
# 56   Person       Human   end of time    5

# %%
Name_Data.rename(columns= {'Row Type': 'First Name', 'Iter Number':'Last Name', 'Power1':'Time'}, inplace=True)
# Out:
# C:\Users\Dhaval\Miniconda3\envs\Practice_Work\lib\site-packages\pandas\core\frame.py:5034: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
Name_Data.head()
drop_Extra.head()
# Out:
#              Row Type       Iter Number             Power1 Speed1 Speed2  \
# 0  first name: Person  last name: Human  date: end of time    NaN    NaN
# 3                Iter                 1                360    108    863
# 4                Iter                 2                684    508    613
# 5                Iter                 3                365    126    825
# 6                Iter                 4                764    594    304
#
#   Electricity Effort Weight Torque  New
# 0         NaN    NaN    NaN    NaN    1
# 3         599    680    442    982    1
# 4         241    249    758    639    1
# 5         407    855    164     86    1
# 6         718    278    674    774    1

# %%
No_Name_Data = drop_Extra[~drop_Extra['Row Type'].str.contains('first name')]

# %%
No_Name_Data.head()
# Out:
#   Row Type Iter Number Power1 Speed1 Speed2 Electricity Effort Weight Torque  \
# 3     Iter           1    360    108    863         599    680    442    982
# 4     Iter           2    684    508    613         241    249    758    639
# 5     Iter           3    365    126    825         407    855    164     86
# 6     Iter           4    764    594    304         718    278    674    774
# 7     Iter           5    487     97    593         206    779    800    123
#
#    New
# 3    1
# 4    1
# 5    1
# 6    1
# 7    1

# %%
Semi_Final = pd.merge(left=Name_Data,right=No_Name_Data,how='inner',on='New')

# %%
Semi_Final.head()
# Out:
#   First Name Last Name          Time  New Row Type Iter Number Power1 Speed1  \
# 0     Person     Human   end of time    1     Iter           1    360    108
# 1     Person     Human   end of time    1     Iter           2    684    508
# 2     Person     Human   end of time    1     Iter           3    365    126
# 3     Person     Human   end of time    1     Iter           4    764    594
# 4     Person     Human   end of time    1     Iter           5    487     97
#
#   Speed2 Electricity Effort Weight Torque
# 0    863         599    680    442    982
# 1    613         241    249    758    639
# 2    825         407    855    164     86
# 3    304         718    278    674    774
# 4    593         206    779    800    123

# %%
Semi_Final.drop(columns= ['New'],inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10008/3125399479.py in <module>
# ----> 1 Semi_Final.drop(columns= ['New'],inplace=True)
#       2
#       3 Final_Data = Semi_Final
#
# ~\Miniconda3\envs\Practice_Work\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\Miniconda3\envs\Practice_Work\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4899                 weight  1.0     0.8
#    4900         """
# -> 4901         return super().drop(
#    4902             labels=labels,
#    4903             axis=axis,
#
# ...

# %%
Semi_Final
# Out:
#       First Name Last Name          Time  Row Type Iter Number Power1 Speed1  \
# 0         Person     Human   end of time      Iter           1    360    108
# 1         Person     Human   end of time      Iter           2    684    508
# 2         Person     Human   end of time      Iter           3    365    126
# 3         Person     Human   end of time      Iter           4    764    594
# 4         Person     Human   end of time      Iter           5    487     97
# ...          ...       ...           ...       ...         ...    ...    ...
# 46404     Person     Human   end of time      Iter           6    879     73
# 46405     Person     Human   end of time   Average         979    641    531
# 46406     Person     Human   end of time   Maximum         783    172    941
# 46407     Person     Human   end of time  Std.Dev.         221    112    717
# 46408     Person     Human   end of time     Total         429      -      -
#
# ...

# %%
Semi_Final.to_csv('Macine_Clean_Data.csv',index=False)
